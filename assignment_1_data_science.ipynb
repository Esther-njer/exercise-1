# %% [markdown]
# <a href="https://colab.research.google.com/github/Esther-njer/exercise-1/blob/main/assignment_1_data_science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
months = ['07/2019','08/2019','09/2019','10/2019','11/2019']
categories=['searches','Direct','Social Media']
data={
'searches':[50,53,59,56,62],
'direct':[39,47,42,51,51],
'Social_Media':[70,80,90,87,92]}

bar_width=0.25
x=np.arange(len(months))

plt.figure(figsize=(10, 6))

bars1=plt.bar(x - bar_width, searches, width=bar_width,label='searches',color='deepskyblue')
bars2=plt.bar(x,direct,width=bar_width, label='Direct',color='orchid')
bars3=plt.bar(x + bar_width,Social_Media,width=bar_width,label='Social_Media',color='gold')

for i in range(len(months)):
plt.text(x[i]-bar

plt.xlabel('months')
plt.ylabel('Visitor in thousands')
plt.title('Visitors by web traffic sources')
plt.xticks(x,months)
plt.legend()
plt.tight_layout ()
plt.show()
